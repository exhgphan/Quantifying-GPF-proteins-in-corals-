# %%
import pandas as pd
Prus_vs_gfp_results = pd.read_csv ("P.rus_vs_gfp.results.txt", sep = "\t", header = None)
Prus_vs_gfp_results.columns = ["query","subject","percent of identical matches", "length", "num of mismatch", "num of gaps", "query start", "query end", "subject start", "subject end", "evalue","bitscore"]
Prus_vs_gfp_results
# Out:
#              query             subject  percent of identical matches  length  \
# 0   XP_015751143.1   OKRP01002500.1.p9                        42.857      77
# 1   XP_015751143.1  OKRP01000565.1.p40                        42.500      80
# 2   XP_015751143.1   OKRP01002500.1.p1                        47.059      68
# 3   XP_015751143.1   OKRP01006776.1.p1                        46.429      56
# 4   XP_015751143.1  OKRP01002141.1.p10                        38.983      59
# 5   XP_015751144.1  OKRP01000565.1.p40                        45.000      80
# 6   XP_015751144.1   OKRP01002500.1.p9                        42.857      77
# 7   XP_015751144.1   OKRP01002500.1.p1                        50.000      68
# 8   XP_015751144.1   OKRP01006776.1.p1                        48.276      58
# 9   XP_015751144.1  OKRP01002141.1.p10                        42.373      59
# 10  XP_015751145.1  OKRP01000565.1.p40                        45.000      80
# ...

# %%
subject_ids = Prus_vs_gfp_results.loc[:,"subject"]
subject_ids = list (subject_ids)
subject_ids

unique_subject_ids = list(set(subject_ids))
print(unique_subject_ids)

number_of_subjects = len(unique_subject_ids)
print(f"The the number of unique subjects is: {number_of_subjects}")
# Out:
# ['OKRP01002500.1.p9', 'OKRP01002500.1.p1', 'OKRP01002141.1.p10', 'OKRP01006776.1.p1', 'OKRP01000565.1.p40']
# The the number of unique subjects is: 5
